# %% [markdown]
# ## Plots

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import pandas as pd
import seaborn as sns

PHYSICAL_CORES=64

def plot(p_data, p_yId, p_xId, p_hueId, p_styleId, p_logScale=False, p_core_marker=False):
    rcParams['figure.figsize'] = 12,8
    rcParams['figure.figsize'] = 12,8
    plot = sns.lineplot(x=p_xId,
                        y=p_yId,
                        hue=p_hueId,
                        style=p_styleId,
                        data=p_data)
    if p_logScale == True:
        plot.set_yscale('log')
        plot.set_xscale('log')
    plot.set(xlabel=p_xId, ylabel=p_yId)
    plt.grid(True,which="both",ls="--",c='lightgray') 

    if(p_core_marker == True):
        plt.axvline(64, linestyle='--', color='red')

    plt.figure(figsize=(1, 1), dpi=80)
    plt.show()

# %% [markdown]
# ### Gauss3

# %% [markdown]
# #### Efficiency by threads

# %%
import pandas as pd
import seaborn as sns

sns.set_theme()
sns.set_style("ticks")

data_frame = pd.read_csv('./e_efficiency_by_threads.csv')

data_frame = data_frame[data_frame.region_id == 'apply']
data_frame['efficiency_type'] = 'relative'

#
# NOTE: calc absolute efficiency
#
data_frame_copy = data_frame.copy()
data_frame_copy['efficiency_type'] = 'absolute'
ref_runtime = data_frame_copy[data_frame.func_id == 'precalc'][data_frame.threads == 1]['runtime'].values[0]
data_frame_copy['efficiency']=data_frame_copy.apply(lambda row: ref_runtime/(row['runtime'] * row['threads']), axis=1)

data_frame = data_frame_copy.append(data_frame)

# display(data_frame)

plot(p_data=data_frame,
    p_yId='runtime',
    p_xId='threads',
    p_hueId='func_id',
    p_styleId=None,
    p_logScale=True,
    p_core_marker=True)
plot(p_data=data_frame,
    p_yId='efficiency',
    p_xId='threads',
    p_hueId='func_id',
    p_styleId='efficiency_type',
    p_logScale=True,
    p_core_marker=True)
# Out:
# /var/folders/zt/h71khkbd7ll9krscx1zncwlc0000gn/T/ipykernel_11469/3309897103.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ref_runtime = data_frame_copy[data_frame.func_id == 'precalc'][data_frame.threads == 1]['runtime'].values[0]

# %% [markdown]
# #### Efficiency by apply_runs

# %% [markdown]
# ##### mul2

# %%
import pandas as pd

data_frame = pd.read_csv('./e_efficiency_by_applyruns.csv')
data_frame = data_frame[data_frame.func_id == 'mul2']
plot(p_data=data_frame,
    p_yId='runtime',
    p_xId='runs',
    p_hueId='impl_id',
    p_styleId='region_id',
    p_logScale=False)
plot(p_data=data_frame,
    p_yId='efficiency',
    p_xId='runs',
    p_hueId='impl_id',
    p_styleId='region_id',
    p_logScale=False)

# %% [markdown]
# ##### pow2

# %%
import pandas as pd

data_frame = pd.read_csv('./e_efficiency_by_applyruns.csv')
data_frame = data_frame[data_frame.func_id == 'pow2']
plot(p_data=data_frame,
    p_yId='runtime',
    p_xId='runs',
    p_hueId='impl_id',
    p_styleId='region_id',
    p_logScale=False)
plot(p_data=data_frame,
    p_yId='efficiency',
    p_xId='runs',
    p_hueId='impl_id',
    p_styleId='region_id',
    p_logScale=False)

# %% [markdown]
# ##### exp

# %%
import pandas as pd

data_frame = pd.read_csv('./e_efficiency_by_applyruns.csv')
data_frame = data_frame[data_frame.func_id == 'exp']
plot(p_data=data_frame,
    p_yId='runtime',
    p_xId='runs',
    p_hueId='impl_id',
    p_styleId='region_id',
    p_logScale=False)
plot(p_data=data_frame,
    p_yId='efficiency',
    p_xId='runs',
    p_hueId='impl_id',
    p_styleId='region_id',
    p_logScale=False)

# %% [markdown]
# ##### pow4_3

# %%
import pandas as pd

data_frame = pd.read_csv('./e_efficiency_by_applyruns.csv')
data_frame = data_frame[data_frame.func_id == 'pow4_3']
plot(p_data=data_frame,
    p_yId='runtime',
    p_xId='runs',
    p_hueId='impl_id',
    p_styleId='region_id',
    p_logScale=False)
plot(p_data=data_frame,
    p_yId='efficiency',
    p_xId='runs',
    p_hueId='impl_id',
    p_styleId='region_id',
    p_logScale=False)

# %% [markdown]
# ##### functions overview

# %%
import pandas as pd

data_frame = pd.read_csv('./e_efficiency_by_applyruns.csv')
data_frame = data_frame[data_frame.region_id == 'apply']
plot(p_data=data_frame,
    p_yId='runtime',
    p_xId='runs',
    p_hueId='func_id',
    p_styleId='impl_id',
    p_logScale=False)
plot(p_data=data_frame,
    p_yId='efficiency',
    p_xId='runs',
    p_hueId='func_id',
    p_styleId='impl_id',
    p_logScale=False)

# %% [markdown]
# #### Efficiency by cells

# %% [markdown]
# ##### mul2

# %%
import pandas as pd

data_frame = pd.read_csv('./e_efficiency_by_cells_old.csv')
data_frame = data_frame[data_frame.func_id == 'mul2']
plot(p_data=data_frame,
    p_yId='runtime',
    p_xId='obj_cells',
    p_hueId='impl_id',
    p_styleId='region_id',
    p_logScale=True)
plot(p_data=data_frame,
    p_yId='efficiency',
    p_xId='obj_cells',
    p_hueId='impl_id',
    p_styleId='region_id',
    p_logScale=True)

# %% [markdown]
# ##### pow2

# %%
import pandas as pd

data_frame = pd.read_csv('./e_efficiency_by_cells_old.csv')
data_frame = data_frame[data_frame.func_id == 'pow2']
plot(p_data=data_frame,
    p_yId='runtime',
    p_xId='obj_cells',
    p_hueId='impl_id',
    p_styleId='region_id',
    p_logScale=True)
plot(p_data=data_frame,
    p_yId='efficiency',
    p_xId='obj_cells',
    p_hueId='impl_id',
    p_styleId='region_id',
    p_logScale=True)

# %% [markdown]
# ##### exp

# %%
import pandas as pd

data_frame = pd.read_csv('./e_efficiency_by_cells_old.csv')
data_frame = data_frame[data_frame.func_id == 'exp']
plot(p_data=data_frame,
    p_yId='runtime',
    p_xId='obj_cells',
    p_hueId='impl_id',
    p_styleId='region_id',
    p_logScale=True)
plot(p_data=data_frame,
    p_yId='efficiency',
    p_xId='obj_cells',
    p_hueId='impl_id',
    p_styleId='region_id',
    p_logScale=True)

# %% [markdown]
# ##### pow4_3

# %%
import pandas as pd

data_frame = pd.read_csv('./e_efficiency_by_cells_old.csv')
data_frame = data_frame[data_frame.func_id == 'pow4_3']
plot(p_data=data_frame,
    p_yId='runtime',
    p_xId='obj_cols',
    p_hueId='impl_id',
    p_styleId='region_id',
    p_logScale=True)
plot(p_data=data_frame,
    p_yId='efficiency',
    p_xId='obj_cols',
    p_hueId='impl_id',
    p_styleId='region_id',
    p_logScale=True)

# %% [markdown]
# ##### functions overview

# %%
import pandas as pd

data_frame = pd.read_csv('./e_efficiency_by_cells.csv')
data_frame = data_frame[data_frame.region_id == 'apply']
plot(p_data=data_frame,
    p_yId='runtime',
    p_xId='obj_cells',
    p_hueId='func_id',
    p_styleId=None,
    p_logScale=True)
plot(p_data=data_frame,
    p_yId='efficiency',
    p_xId='obj_cells',
    p_hueId='func_id',
    p_styleId=None,
    p_logScale=True)

# %% [markdown]
# #### Arithmetic Intensity by cost

# %% [markdown]
# ##### Empirically Determined Parameters
#
# based on `src_master_thesis/node_characterization/likwid-bench_gauss3.out`:

# %%
emp_flops_max=2459.32383
emp_mem_band=233.172

# %%
import pandas as pd
import seaborn as sns

sns.set_theme()
sns.set_style("ticks")

maschine_balance=emp_flops_max/emp_mem_band

ops_data = pd.read_csv('./e_measure_ops.csv')
ops_data['func_id'] = ops_data.apply(lambda row: f'nonlinear_{row["func_id"].lower()}', axis=1)


roofline_data = pd.read_csv('./e_roofline.csv')

roofline_data = roofline_data[roofline_data.region_id == 'apply']
roofline_data = roofline_data.merge(ops_data, left_on='impl_id', right_on='func_id')
roofline_data['func_id'] = 'function cost'
roofline_data['ai']=roofline_data.apply(lambda row: (row['mflop_s']/row['mbytes_s']), axis=1)

#
# NOTE: add maschine balance
#
roofline_data_copy = roofline_data.copy()
roofline_data_copy['func_id'] = 'maschine balance'
roofline_data_copy['ai'] = maschine_balance
roofline_data = roofline_data_copy.append(roofline_data)

# display(roofline_data)

plot(p_data=roofline_data,
    p_yId='ai',
    p_xId='ops',
    p_hueId='func_id',
    p_styleId=None,
    p_logScale=False)

# %% [markdown]
# #### Performance by cost

# %%
import pandas as pd
import seaborn as sns

sns.set_theme()
sns.set_style("ticks")

ops_data = pd.read_csv('./e_measure_ops.csv')
ops_data['func_id'] = ops_data.apply(lambda row: f'nonlinear_{row["func_id"].lower()}', axis=1)

roofline_data = pd.read_csv('./e_roofline.csv')
roofline_data = roofline_data[roofline_data.region_id == 'apply']
roofline_data = roofline_data.merge(ops_data, left_on='impl_id', right_on='func_id')

display(roofline_data)

roofline_data['gflop_s']=roofline_data.apply(lambda row: (row['mflop_s']/1000), axis=1)


plot(p_data=roofline_data,
    p_yId='gflop_s',
    p_xId='ops',
    p_hueId=None,
    p_styleId=None,
    p_logScale=False)
# Out:
#   node_id    bench_id             impl_id region_id  obj_cols  obj_rows  \
# 0  gauss4  e_roofline      nonlinear_pow2     apply      1024      1024
# 1  gauss4  e_roofline       nonlinear_exp     apply      1024      1024
# 2  gauss4  e_roofline    nonlinear_pow4_3     apply      1024      1024
# 3  gauss4  e_roofline  nonlinear_costly_0     apply      1024      1024
# 4  gauss4  e_roofline  nonlinear_costly_1     apply      1024      1024
# 5  gauss3  e_roofline  nonlinear_costly_2     apply      1024      1024
#
#    obj_levels   obj_cells  threads      mflop_s     mbytes_s  \
# 0        1024  1073741824      128  200284.1210  225663.5252
# 1        1024  1073741824      128  899734.5041  196085.3308
# 2        1024  1073741824      128  739720.6792   72449.4885
# 3        1024  1073741824      128  720769.8869   52070.6369
# 4        1024  1073741824      128  734015.8833   35528.6988
# 5        1024  1073741824      128  738829.0969   43622.7623
#
#               func_id  ops
# 0      nonlinear_pow2   14
# 1       nonlinear_exp  150
# 2    nonlinear_pow4_3  374
# 3  nonlinear_costly_0  566
# 4  nonlinear_costly_1  758
# 5  nonlinear_costly_2  746
