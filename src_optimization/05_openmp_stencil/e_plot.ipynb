# %% [markdown]
# ## Cache Plots

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import pandas as pd
import seaborn as sns

PHYSICAL_CORES=64

def plot(p_data, p_yId, p_xId, p_hueId, p_styleId, p_logScale=False, p_core_marker=False):
    rcParams['figure.figsize'] = 11.7,8.27
    plot = sns.lineplot(x=p_xId,
                        y=p_yId,
                        hue=p_hueId,
                        style=p_styleId,
                        data=p_data)
    if p_logScale == True:
        plot.set_yscale('log')
        plot.set_xscale('log')
    plot.set(xlabel='threads', ylabel=p_yId)
    plt.grid(True,which="both",ls="--",c='lightgray') 

    if(p_core_marker == True):
        plt.axvline(64, linestyle='--', color='red')

    plt.figure(figsize=(1, 1), dpi=80)
    plt.show()

# %% [markdown]
# ### Gauss3

# %% [markdown]
# #### Strong Scaling

# %%
import pandas as pd

data_frame = pd.read_csv('./e_linear_stencil_para_strong_scale_env_gauss3.csv')
data_frame = data_frame[data_frame.region_id == 'apply']
plot(p_data=data_frame,
    p_yId='runtime',
    p_xId='threads',
    p_hueId='bench_id',
    p_styleId=None,
    p_logScale=True,
    p_core_marker=True)
plot(p_data=data_frame,
    p_yId='efficiency',
    p_xId='threads',
    p_hueId='bench_id',
    p_styleId=None,
    p_logScale=True,
    p_core_marker=True)

# %%
import pandas as pd

data_frame = pd.read_csv('./e_linear_stencil_para_strong_scale_env_gauss3_filter.csv')
data_frame = data_frame[data_frame.region_id == 'apply']

#
# NOTE: calc absolute efficiency
#
ref_runtime = data_frame[data_frame.bench_id == 'strong_scale_env_nobind'][data_frame.threads == 1]['runtime'].values[0]
data_frame = data_frame.assign(efficiency_abs=lambda p_entry: ref_runtime/(p_entry.runtime * p_entry.threads))

plot(p_data=data_frame,
    p_yId='runtime',
    p_xId='threads',
    p_hueId='bench_id',
    p_styleId=None,
    p_logScale=True,
    p_core_marker=True)
plot(p_data=data_frame,
    p_yId='efficiency_abs',
    p_xId='threads',
    p_hueId='bench_id',
    p_styleId=None,
    p_logScale=True,
    p_core_marker=True)
# Out:
# /var/folders/zt/h71khkbd7ll9krscx1zncwlc0000gn/T/ipykernel_15108/1316210565.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ref_runtime = data_frame[data_frame.bench_id == 'strong_scale_env_nobind'][data_frame.threads == 1]['runtime'].values[0]

# %% [markdown]
# #### Strong vs. Weak Scaling

# %%
import pandas as pd

data_frame = pd.read_csv('./e_linear_stencil_para_strong_weak_scale_env_gauss3.csv')
# data_frame = data_frame[data_frame.region_id == 'apply']
plot(p_data=data_frame,
    p_yId='runtime',
    p_xId='threads',
    p_hueId='bench_id',
    p_styleId='region_id',
    p_logScale=False,
    p_core_marker=True)
plot(p_data=data_frame,
    p_yId='efficiency',
    p_xId='threads',
    p_hueId='bench_id',
    p_styleId='region_id',
    p_logScale=False,
    p_core_marker=True)

# %%
import pandas as pd

data_frame = pd.read_csv('./e_linear_stencil_para_strong_weak_scale_env_gauss3_01.csv')
# data_frame = data_frame[data_frame.region_id == 'apply']
plot(p_data=data_frame,
    p_yId='runtime',
    p_xId='threads',
    p_hueId='bench_id',
    p_styleId='region_id',
    p_logScale=False,
    p_core_marker=True)
plot(p_data=data_frame,
    p_yId='efficiency',
    p_xId='threads',
    p_hueId='bench_id',
    p_styleId='region_id',
    p_logScale=False,
    p_core_marker=True)

# %% [markdown]
# #### Strong Scaling: Env vs likwid

# %%
import pandas as pd

data_frame = pd.read_csv('./e_linear_stencil_para_strong_env_likwid_gauss3.csv')
data_frame = data_frame[data_frame.region_id == 'apply']
plot(p_data=data_frame,
    p_yId='runtime',
    p_xId='threads',
    p_hueId='bench_id',
    p_styleId='region_id',
    p_logScale=False,
    p_core_marker=True)
plot(p_data=data_frame,
    p_yId='efficiency',
    p_xId='threads',
    p_hueId='bench_id',
    p_styleId='region_id',
    p_logScale=False,
    p_core_marker=True)
